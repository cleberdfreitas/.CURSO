# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/refs/heads/main/pacientes.json'
url2 = 'https://raw.githubusercontent.com/alura-cursos/Pandas/refs/heads/main/pacientes_2.json'

# %%
dados_paciente = pd.read_json(url)
dados_paciente
# Out:
#      ID_paciente Doenca_cardiaca    IMC Fumante Consumo_alcool  AVC  \
# 0              0             Nao  16.60     Sim            Nao  Nao
# 1              1             Nao  20.34     Nao            Nao  Sim
# 2              2             Nao  26.58     Sim            Nao  Nao
# 3              3             Nao  24.21     Nao            Nao  Nao
# 4              4             Nao  23.71     Nao            Nao  Nao
# ..           ...             ...    ...     ...            ...  ...
# 995          995             Nao  28.29     Sim            Nao  Nao
# 996          996             Nao  25.69     Sim            Nao  Nao
# 997          997             Sim  26.99     Nao            Nao  Nao
# 998          998             Nao  44.29     Nao            Nao  Nao
# 999          999             Nao  25.83     Nao            Nao  Nao
#
#      Saude_fisica  Saude_mental Dificuldade_caminhar Sexo_biologico  \
# 0               3            30                  Nao       Feminino
# ...

# %%
dados_paciente2 = pd.read_json(url2)
dados_paciente2
# Out:
#                                     Pesquisa   Ano  \
# 0  Principais Indicadores de Doenca Cardiaca  2020
# 1  Principais Indicadores de Doenca Cardiaca  2020
# 2  Principais Indicadores de Doenca Cardiaca  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Faixa_etaria': '55-59', 'Sexo_bi...
# 1  {'ID': '02', 'Faixa_etaria': '80 ou +', 'Sexo_...
# 2  {'ID': '03', 'Faixa_etaria': '65-69', 'Sexo_bi...

# %%
df_normalizado = pd.json_normalize(dados_paciente2['Pacientes'])
df_normalizado
# Out:
#    ID Faixa_etaria Sexo_biologico    Raça    IMC Fumante Consumo_alcool  \
# 0  01        55-59       Feminino  Branca  16.60     Sim            Nao
# 1  02      80 ou +       Feminino  Branca  20.34     Nao            Nao
# 2  03        65-69      Masculino  Branca  26.58     Sim            Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Atividade_fisica  \
# 0             3            30                  Nao              Sim
# 1             0             0                  Nao              Sim
# 2            20            30                  Nao              Sim
#
#   Saude_geral  Horas_sono                Problemas_saude
# 0   Muito boa           5  [Diabetes, Asma, Cancer_pele]
# 1   Muito boa           7                          [AVC]
# 2   Muito boa           8               [diabetes, Asma]

# %%
dados = {'Pesquisa': 'Principais Indicadores de Doenca Cardiaca', 'Ano': 2020, 'Numero_Pacientes':3}
df = pd.json_normalize(dados)
df
# Out:
#                                     Pesquisa   Ano  Numero_Pacientes
# 0  Principais Indicadores de Doenca Cardiaca  2020                 3

# %%
json_lista = [
    { 'ID': '01', 'Faixa_etaria': '55-59', 'Sexo_biologico': 'feminino'},
    { 'ID': '02', 'Faixa_etaria': '80 ou +', 'Sexo_biologico': 'feminino'}
]
pd.json_normalize(json_lista)
# Out:
#    ID Faixa_etaria Sexo_biologico
# 0  01        55-59       feminino
# 1  02      80 ou +       feminino

# %%
json_obj = {
    'ID': '01',
    'Faixa_etaria': '55-59',
    'Sexo_biologico': 'Feminino',
    'Saude': {'Dificuldade_caminhar': 'Nao',
              'Atividade_fisica': 'Sim',
              'IMC': 16.6,
              'Doenca_cardiaca': 'Nao',
          }
      }
pd.json_normalize(json_obj)
# Out:
#    ID Faixa_etaria Sexo_biologico Saude.Dificuldade_caminhar  \
# 0  01        55-59       Feminino                        Nao
#
#   Saude.Atividade_fisica  Saude.IMC Saude.Doenca_cardiaca
# 0                    Sim       16.6                   Nao

# %%
json_list = [
    {
    'ID': '01',
    'Faixa_etaria': '55-59',
    'Sexo_biologico': 'Feminino',
    'Saude': {'Dificuldade_caminhar': 'Nao',
              'Atividade_fisica': 'Sim',
              'IMC': 16.6,
              'Doenca_cardiaca': 'Nao',
          }
      },
      {
          'ID': '02',
          'Faixa_etaria': '80 ou +',
          'Sexo_biologico': 'Feminino',
          'Saude': {'Dificuldade_caminhar': 'Nao',
                    'Atividade_fisica': 'Sim',
                    'IMC': 20.34,
                    'Doenca_cardiaca': 'Sim'}
       }
       ]
pd.json_normalize(json_list)
# Out:
#    ID Faixa_etaria Sexo_biologico Saude.Dificuldade_caminhar  \
# 0  01        55-59       Feminino                        Nao
# 1  02      80 ou +       Feminino                        Nao
#
#   Saude.Atividade_fisica  Saude.IMC Saude.Doenca_cardiaca
# 0                    Sim      16.60                   Nao
# 1                    Sim      20.34                   Sim

# %%
dados_dict = {
  "Pesquisa": "Principais Indicadores de Doenca Cardiaca",
  "Ano": 2020,
  "Pacientes": [
    {
      "ID": "01",
      "Faixa_etaria": "55-59",
      "Sexo_biologico": "Feminino",
      "Raça": "Branca",
      "IMC": 16.6,
      "Fumante": "Sim",
      "Consumo_alcool": "Nao",
      "Saude_fisica": 3,
      "Saude_mental": 30,
      "Dificuldade_caminhar": "Nao",
      "Atividade_fisica": "Sim",
      "Saude_geral": "Muito boa",
      "Horas_sono": 5,
      "Problemas_saude": [
        "Diabetes",
        "Asma",
        "Cancer_pele"
      ]
    },
    {
      "ID": "02",
      "Faixa_etaria": "80 ou +",
      "Sexo_biologico": "Feminino",
      "Raça": "Branca",
      "IMC": 20.34,
      "Fumante": "Nao",
      "Consumo_alcool": "Nao",
      "Saude_fisica": 0,
      "Saude_mental": 0,
      "Dificuldade_caminhar": "Nao",
      "Atividade_fisica": "Sim",
      "Saude_geral": "Muito boa",
      "Horas_sono": 7,
      "Problemas_saude": [
        "AVC"
      ]
    },
    {
      "ID": "03",
      "Faixa_etaria": "65-69",
      "Sexo_biologico": "Masculino",
      "Raça": "Branca",
      "IMC": 26.58,
      "Fumante": "Sim",
      "Consumo_alcool": "Nao",
      "Saude_fisica": 20,
      "Saude_mental": 30,
      "Dificuldade_caminhar": "Nao",
      "Atividade_fisica": "Sim",
      "Saude_geral": "Muito boa",
      "Horas_sono": 8,
      "Problemas_saude": [
        "diabetes",
        "Asma"
      ]
    }
  ]
}

pd.json_normalize(dados_dict)
# Out:
#                                     Pesquisa   Ano  \
# 0  Principais Indicadores de Doenca Cardiaca  2020
#
#                                            Pacientes
# 0  [{'ID': '01', 'Faixa_etaria': '55-59', 'Sexo_b...

# %%
pd.json_normalize(dados_dict['Pacientes'])
pd.json_normalize(dados_dict, record_path=['Pacientes'])
# Out:
#    ID Faixa_etaria Sexo_biologico    Raça    IMC Fumante Consumo_alcool  \
# 0  01        55-59       Feminino  Branca  16.60     Sim            Nao
# 1  02      80 ou +       Feminino  Branca  20.34     Nao            Nao
# 2  03        65-69      Masculino  Branca  26.58     Sim            Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Atividade_fisica  \
# 0             3            30                  Nao              Sim
# 1             0             0                  Nao              Sim
# 2            20            30                  Nao              Sim
#
#   Saude_geral  Horas_sono                Problemas_saude
# 0   Muito boa           5  [Diabetes, Asma, Cancer_pele]
# 1   Muito boa           7                          [AVC]
# 2   Muito boa           8               [diabetes, Asma]

# %%
pd.json_normalize(
    dados_dict,
    record_path =['Pacientes'],
    meta=['Pesquisa', 'Ano']
)
# Out:
#    ID Faixa_etaria Sexo_biologico    Raça    IMC Fumante Consumo_alcool  \
# 0  01        55-59       Feminino  Branca  16.60     Sim            Nao
# 1  02      80 ou +       Feminino  Branca  20.34     Nao            Nao
# 2  03        65-69      Masculino  Branca  26.58     Sim            Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Atividade_fisica  \
# 0             3            30                  Nao              Sim
# 1             0             0                  Nao              Sim
# 2            20            30                  Nao              Sim
#
#   Saude_geral  Horas_sono                Problemas_saude  \
# 0   Muito boa           5  [Diabetes, Asma, Cancer_pele]
# 1   Muito boa           7                          [AVC]
# 2   Muito boa           8               [diabetes, Asma]
#
#                                     Pesquisa   Ano
# 0  Principais Indicadores de Doenca Cardiaca  2020
# 1  Principais Indicadores de Doenca Cardiaca  2020
# ...

# %%
# Importante: Na aula nós realizamos a normalização em um arquivo com o formato
# JSON. No entanto, a função json_normalize() aceita apenas um dicionário ou uma
# lista de dicionários. Por isso, no vídeo foi usada a estratégia de usar o
# código: pd.json_normalize(dados_pacientes_2['Pacientes']).
# Porém, se tentarmos usar parâmetros da função json_normalize em um arquivo
# JSON podem surgir erros. Para contornar isso, precisamos importar o módulo
# json e ler os arquivos conforme o código abaixo:


# #Importando a biblioteca Pandas
# import pandas as pd

# #Importando o módulo JSON
# import json

# #Lendo o arquivo json usando o módulo Python JSON
# with open('pacientes_2.json','r') as f:
#     dados = json.loads(f.read())

# #Normalizando os dados com os parâmetros record_path e meta
# pd.json_normalize(dados, record_path='Pacientes', meta=['Pesquisa', 'Ano'])

# %%
df_normalizado.to_json('historico_pacientes_normalizado.json')

# %%
pd.read_json('historico_pacientes_normalizado.json')
# Out:
#    ID Faixa_etaria Sexo_biologico    Raça    IMC Fumante Consumo_alcool  \
# 0   1        55-59       Feminino  Branca  16.60     Sim            Nao
# 1   2      80 ou +       Feminino  Branca  20.34     Nao            Nao
# 2   3        65-69      Masculino  Branca  26.58     Sim            Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Atividade_fisica  \
# 0             3            30                  Nao              Sim
# 1             0             0                  Nao              Sim
# 2            20            30                  Nao              Sim
#
#   Saude_geral  Horas_sono                Problemas_saude
# 0   Muito boa           5  [Diabetes, Asma, Cancer_pele]
# 1   Muito boa           7                          [AVC]
# 2   Muito boa           8               [diabetes, Asma]

# %% [markdown]
# ### para saber mais : dadps JSON de API

# %%
import requests
import json

dados_frutas = requests.get('https://fruityvice.com/api/fruit/all')
resultado = json.loads(dados_frutas.text)
pd.DataFrame(resultado)
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# ...

# %%
import pandas as pd
dados_frutas_normalizado = pd.json_normalize(resultado)
dados_frutas_normalizado
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# ...
